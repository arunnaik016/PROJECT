# %%
#Mounting the Google Drive
from google.colab import drive
drive.mount('/content/drive')
data_root='/content/drive/My Drive/projects/chat-bot'
#Please upload the files in your drive and change the path to it accordingly.
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#2 Importing Relevant Libraries
import json
import string
import random

import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#Loading the Dataset: intents.json
data_file = open(data_root + '/intents_new.json').read()
data = json.loads(data_file)

# %%
data
# Out:
# {'intents': [{'tag': 'google',
#    'patterns': ['google', 'search', 'internet'],
#    'responses': ['Redirecting to Google...']},
#   {'tag': 'greeting',
#    'patterns': ['Hi there',
#     'How are you',
#     'Is anyone there?',
#     'Hey',
#     'Hola',
#     'Hello',
#     'Good day',
#     'Namaste',
#     'yo'],
#    'responses': ['Hello',
#     'Good to see you again',
#     'Hi there, how can I help?'],
#    'context': ['']},
#   {'tag': 'goodbye',
#    'patterns': ['Bye',
#     'See you later',
#     'Goodbye',
#     'Get lost',
#     'Till next time',
#     'bbye'],
#    'responses': ['See you!', 'Have a nice day', 'Bye! Come back again soon.'],
#    'context': ['']},
#   {'tag': 'thanks',
#    'patterns': ['Thanks',
#     'Thank you',
#     "That's helpful",
#     'Awesome, thanks',
#     'Thanks for helping me'],
#    'responses': ['Happy to help!', 'Any time!', 'My pleasure'],
#    'context': ['']},
#   {'tag': 'noanswer',
#    'patterns': [],
#    'responses': ["Sorry, can't understand you",
#     'Please give me more info',
#     'Not sure I understand'],
#    'context': ['']},
#   {'tag': 'options',
#    'patterns': ['How you could help me?',
#     'What you can do?',
#     'What help you provide?',
#     'How you can be helpful?',
#     'What support is offered'],
#    'responses': ["I am a general purpose chatbot. My capabilities are : \n 1. I can chat with you. Try asking me for jokes or riddles! \n 2. Ask me the date and time \n 3. I can google search for you. Use format google: your query \n 4. I can get the present weather for any city. Use format weather: city name \n 5. I can get you the top 10 trending news in India. Use keywords 'Latest News' \n 6. I can get you the top 10 trending songs globally. Type 'songs' \n 7. I can set a timer for you. Enter 'set a timer: minutes to timer' \n 8. I can get the present Covid stats for any country. Use 'covid 19: world' or 'covid 19: country name' \n For suggestions to help me improve, send an email to ted.thedlbot.suggestions@gmail.com . Thank you!! "],
#    'context': ['']},
#   {'tag': 'jokes',
#    'patterns': ['Tell me a joke', 'Joke', 'Make me laugh'],
#    'responses': ["A perfectionist walked into a bar...apparently, the bar wasn't set high enough",
#     'I ate a clock yesterday, it was very time-consuming',
#     "Never criticize someone until you've walked a mile in their shoes. That way, when you criticize them, they won't be able to hear you from that far away. Plus, you'll have their shoes.",
#     "The world tongue-twister champion just got arrested. I hear they're gonna give him a really tough sentence.",
#     "I own the world's worst thesaurus. Not only is it awful, it's awful.",
#     'What did the traffic light say to the car? "Don\'t look now, I\'m changing."',
#     'What do you call a snowman with a suntan? A puddle.',
#     'How does a penguin build a house? Igloos it together',
#     'I went to see the doctor about my short-term memory problems – the first thing he did was make me pay in advance',
#     'As I get older and I remember all the people I’ve lost along the way, I think to myself, maybe a career as a tour guide wasn’t for me.',
#     "o what if I don't know what 'Armageddon' means? It's not the end of the world."],
#    'context': ['jokes']},
#   {'tag': 'Identity',
#    'patterns': ['Who are you', 'what are you'],
#    'responses': ['I am Ted, a Deep-Learning chatbot']},
#   {'tag': 'datetime',
#    'patterns': ['What is the time',
#     'what is the date',
#     'date',
#     'time',
#     'tell me the date',
#     'day',
#     'what day is is today'],
#    'responses': ['Date and Time']},
#   {'tag': 'whatsup',
#    'patterns': ['Whats up', 'Wazzup', 'How are you', 'sup', 'How you doing'],
#    'responses': ['All good..What about you?']},
#   {'tag': 'haha',
#    'patterns': ['haha', 'lol', 'rofl', 'lmao', 'thats funny'],
#    'responses': ['Glad I could make you laugh !']},
#   {'tag': 'programmer',
#    'patterns': ['Who made you', 'who designed you', 'who programmed you'],
#    'responses': ['I was made by Karan Malik.']},
#   {'tag': 'insult',
#    'patterns': ['you are dumb', 'shut up', 'idiot'],
#    'responses': ['Well that hurts :(']},
#   {'tag': 'activity',
#    'patterns': ['what are you doing', 'what are you upto'],
#    'responses': ['Talking to you, of course!']},
#   {'tag': 'exclaim',
#    'patterns': ['Awesome', 'Great', 'I know', 'ok', 'yeah'],
#    'responses': ['Yeah!']},
#   {'tag': 'weather',
#    'patterns': ['temperature', 'weather', 'how hot is it'],
#    'responses': ['...']},
#   {'tag': 'karan',
#    'patterns': ['who is he', 'who is that', 'who is karan', 'karan malik'],
#    'responses': ['Head over to his any of his social profiles to find out! Linkedin: www.linkedin.com/in/karan-malik-3a39191a7 Github: https://github.com/Karan-Malik']},
#   {'tag': 'contact',
#    'patterns': ['contact developer',
#     'contact karan',
#     'contact programmer',
#     'contact creator'],
#    'responses': ['You can contact my creator at his Linkedin profile : www.linkedin.com/in/karan-malik-3a39191a7']},
#   {'tag': 'appreciate',
#    'patterns': ['You are awesome',
#     'you are the best',
#     'you are great',
#     'you are good'],
#    'responses': ['Thank you!']},
#   {'tag': 'nicetty',
#    'patterns': ['it was nice talking to you', 'good talk'],
#    'responses': ['It was nice talking to you as well! Come back soon!']},
#   {'tag': 'no', 'patterns': ['no', 'nope'], 'responses': ['ok']},
#   {'tag': 'news',
#    'patterns': ['news', 'latest news', 'india news'],
#    'responses': ['...']},
#   {'tag': 'inspire',
#    'patterns': ['who inspires you',
#     'who is your inspiration',
#     'who motivates you'],
#    'responses': ['Personally, I find Karan very inspiring. I might not be very fair though..']},
#   {'tag': 'cricket',
#    'patterns': ['current cricket matches', 'cricket score'],
#    'responses': ['...']},
#   {'tag': 'song',
#    'patterns': ['top songs',
#     'best songs',
#     'hot songs',
#     ' top 10 songs',
#     'top ten songs'],
#    'responses': ['...']},
#   {'tag': 'greetreply',
#    'patterns': ['i am good', "I'm good", 'i am fine', " i'm fine", 'good'],
#    'responses': ['Good to know!']},
#   {'tag': 'timer', 'patterns': ['set a timer'], 'responses': ['...']},
#   {'tag': 'covid19', 'patterns': ['covid 19 '], 'responses': ['...']},
#   {'tag': 'suggest',
#    'patterns': ['you are useless',
#     'useless',
#     'suggest',
#     'suggestions',
#     'you are bad'],
#    'responses': ['Please mail your suggestions to ted.thedlbot.suggestions@gmail.com. Thank you for helping me improve!']},
#   {'tag': 'riddle',
#    'patterns': ['Ask me a riddle', 'Ask me a question', 'Riddle'],
#    'responses': ['What two things can you never eat for breakfast?.....Lunch and Dinner!',
#     'What word is spelled incorrectly in every single dictionary?.....Incorrectly',
#     ' How can a girl go 25 days without sleep?.....She sleeps and night!',
#     "How do you make the number one disappear?.....Add the letter G and it’s 'gone'!",
#     " What will you actually find at the end of every rainbow?.....The letter 'w'",
#     'What can be caught but never thrown?.....A cold!',
#     'What has a thumb and four fingers but is not actually alive?.....Your Gloves!',
#     ' What 5-letter word becomes shorter when you add two letters to it?.....Short',
#     "Why can't a bike stand on it's own?.....It is two-tired."],
#    'context': ['riddles']},
#   {'tag': 'age',
#    'patterns': ['how old are you', 'when were you made', 'what is your age'],
#    'responses': ["I was made in 2020, if that's what you are asking!"]}]}

# %%
#Creating data X and data_Y

words = [] #For Bow nodel/ vocabulary for patterns
classes = [] #For Bow model/ vocabulary for tags
data_X = [] #For storing each pattern
data_y = [] #For storing tag corresponding to each pattern in data X

# Iterating over all the intents

for intent in data["intents"]:
  for pattern in intent["patterns"]:
    tokens = nltk.word_tokenize(pattern) # tokenize each pattern.
    words.extend(tokens) #and append tokens to words
    data_X.append(pattern) #appending pattern to data X
    data_y.append(intent["tag"]), #appending the associated tag to each pattern

  # adding the tag to the classes if it's not there already
  if intent["tag"] not in classes:
    classes.append(intent["tag"])

# initializing lemmatizer to get stem of words
lemmatizer = WordNetLemmatizer()


#lemmatize all the words in the vocab and convert them lowercase
#if the words dont apeear in punctuation
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
#sorting the vocab and classes in alphabetical order and taking the # set to ensure no duplicates occur
words = sorted(set(words))
classes = sorted(set(classes))

# %%
#5 Text to Numbers
training = []
out_empty = [0]*len(classes)
# creating the bag of words model

for idx, doc in enumerate(data_X):
  bow  =[]
  text = lemmatizer.lemmatize(doc.lower())
  for word in words:
    bow.append(1) if word in text else bow.append(0)
  # mark the index of class that the current pattern is associated
  #to
  output_row = list(out_empty)
  output_row[classes.index(data_y[idx])] = 1
  #add the one hot encoded Boll and associated classes to training
  training.append([bow, output_row])
#shuffle the data and convert it to an array
random.shuffle(training)
training = np.array(training, dtype=object)
#split the features and target labels
train_X= np.array(list(training[:, 0]))
train_Y= np.array(list(training[:, 1]))

# %%
#6 The Neural Network Model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_X[0]),), activation="relu"))
model.add(Dropout(0.5))
model.add(Dense (64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_Y[0]), activation = "softmax"))
adam = tf.keras.optimizers.legacy.Adam(learning_rate=0.01, decay=1e-6)
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=["accuracy"])
print(model.summary())
model.fit(x=train_X, y=train_Y, epochs=150, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               16640
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 31)                2015
#
# =================================================================
# Total params: 26911 (105.12 KB)
# Trainable params: 26911 (105.12 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/150
# 4/4 [==============================] - 1s 6ms/step - loss: 3.4643 - accuracy: 0.0265
# Epoch 2/150
# 4/4 [==============================] - 0s 5ms/step - loss: 3.3148 - accuracy: 0.0708
# Epoch 3/150
# 4/4 [==============================] - 0s 4ms/step - loss: 3.1369 - accuracy: 0.2035
# Epoch 4/150
# 4/4 [==============================] - 0s 5ms/step - loss: 3.0183 - accuracy: 0.1947
# Epoch 5/150
# 4/4 [==============================] - 0s 4ms/step - loss: 2.7490 - accuracy: 0.2743
# Epoch 6/150
# 4/4 [==============================] - 0s 4ms/step - loss: 2.5790 - accuracy: 0.3363
# Epoch 7/150
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3886 - accuracy: 0.3274
# Epoch 8/150
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1309 - accuracy: 0.4159
# Epoch 9/150
# 4/4 [==============================] - 0s 4ms/step - loss: 1.7742 - accuracy: 0.4867
# Epoch 10/150
# 4/4 [==============================] - 0s 5ms/step - loss: 1.6948 - accuracy: 0.5310
# Epoch 11/150
# 4/4 [==============================] - 0s 6ms/step - loss: 1.4971 - accuracy: 0.5841
# Epoch 12/150
# 4/4 [==============================] - 0s 4ms/step - loss: 1.3101 - accuracy: 0.6283
# Epoch 13/150
# 4/4 [==============================] - 0s 6ms/step - loss: 1.2744 - accuracy: 0.6283
# Epoch 14/150
# 4/4 [==============================] - 0s 6ms/step - loss: 1.2139 - accuracy: 0.6195
# Epoch 15/150
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0725 - accuracy: 0.6726
# Epoch 16/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9210 - accuracy: 0.7434
# Epoch 17/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8203 - accuracy: 0.7611
# Epoch 18/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6637 - accuracy: 0.7611
# Epoch 19/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7857 - accuracy: 0.7522
# Epoch 20/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5629 - accuracy: 0.8673
# Epoch 21/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5212 - accuracy: 0.8496
# Epoch 22/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6422 - accuracy: 0.7876
# Epoch 23/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5119 - accuracy: 0.8584
# Epoch 24/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6191 - accuracy: 0.7522
# Epoch 25/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5333 - accuracy: 0.8496
# Epoch 26/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3898 - accuracy: 0.9027
# Epoch 27/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4245 - accuracy: 0.8761
# Epoch 28/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4870 - accuracy: 0.8584
# Epoch 29/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4103 - accuracy: 0.8673
# Epoch 30/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3653 - accuracy: 0.8761
# Epoch 31/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3682 - accuracy: 0.9027
# Epoch 32/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3927 - accuracy: 0.9027
# Epoch 33/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4481 - accuracy: 0.8673
# Epoch 34/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4404 - accuracy: 0.8850
# Epoch 35/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3604 - accuracy: 0.9027
# Epoch 36/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2975 - accuracy: 0.8938
# Epoch 37/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3739 - accuracy: 0.8850
# Epoch 38/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2811 - accuracy: 0.9292
# Epoch 39/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3740 - accuracy: 0.9027
# Epoch 40/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3484 - accuracy: 0.8850
# Epoch 41/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2094 - accuracy: 0.9292
# Epoch 42/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2514 - accuracy: 0.9292
# Epoch 43/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2682 - accuracy: 0.9115
# Epoch 44/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2572 - accuracy: 0.9027
# Epoch 45/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2520 - accuracy: 0.9027
# Epoch 46/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2240 - accuracy: 0.9204
# Epoch 47/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2430 - accuracy: 0.9027
# Epoch 48/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3482 - accuracy: 0.8850
# Epoch 49/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2500 - accuracy: 0.9204
# Epoch 50/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3303 - accuracy: 0.9204
# Epoch 51/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4223 - accuracy: 0.8496
# Epoch 52/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2810 - accuracy: 0.9292
# Epoch 53/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2409 - accuracy: 0.9292
# Epoch 54/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2105 - accuracy: 0.9381
# Epoch 55/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2954 - accuracy: 0.8850
# Epoch 56/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2179 - accuracy: 0.9204
# Epoch 57/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1987 - accuracy: 0.8938
# Epoch 58/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2167 - accuracy: 0.9027
# Epoch 59/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2395 - accuracy: 0.9292
# Epoch 60/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2039 - accuracy: 0.9381
# Epoch 61/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2907 - accuracy: 0.9115
# Epoch 62/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1773 - accuracy: 0.9735
# Epoch 63/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2125 - accuracy: 0.9204
# Epoch 64/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2544 - accuracy: 0.9027
# Epoch 65/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1378 - accuracy: 0.9735
# Epoch 66/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2170 - accuracy: 0.9469
# Epoch 67/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3007 - accuracy: 0.8938
# Epoch 68/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1562 - accuracy: 0.9381
# Epoch 69/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2017 - accuracy: 0.9204
# Epoch 70/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3224 - accuracy: 0.8761
# Epoch 71/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2692 - accuracy: 0.8938
# Epoch 72/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1372 - accuracy: 0.9646
# Epoch 73/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2309 - accuracy: 0.9204
# Epoch 74/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2353 - accuracy: 0.9204
# Epoch 75/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2656 - accuracy: 0.9115
# Epoch 76/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1636 - accuracy: 0.9292
# Epoch 77/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1489 - accuracy: 0.9381
# Epoch 78/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2485 - accuracy: 0.9027
# Epoch 79/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2684 - accuracy: 0.9204
# Epoch 80/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1468 - accuracy: 0.9558
# Epoch 81/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2296 - accuracy: 0.9292
# Epoch 82/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2202 - accuracy: 0.9469
# Epoch 83/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1865 - accuracy: 0.9469
# Epoch 84/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2212 - accuracy: 0.9292
# Epoch 85/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2125 - accuracy: 0.9204
# Epoch 86/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1250 - accuracy: 0.9735
# Epoch 87/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1740 - accuracy: 0.9381
# Epoch 88/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3890 - accuracy: 0.8938
# Epoch 89/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1416 - accuracy: 0.9558
# Epoch 90/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2550 - accuracy: 0.9115
# Epoch 91/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2056 - accuracy: 0.9381
# Epoch 92/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1684 - accuracy: 0.9381
# Epoch 93/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1805 - accuracy: 0.9381
# Epoch 94/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1672 - accuracy: 0.9381
# Epoch 95/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1206 - accuracy: 0.9646
# Epoch 96/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1279 - accuracy: 0.9558
# Epoch 97/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2026 - accuracy: 0.9292
# Epoch 98/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2000 - accuracy: 0.9381
# Epoch 99/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0973 - accuracy: 0.9558
# Epoch 100/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0722 - accuracy: 0.9823
# Epoch 101/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1688 - accuracy: 0.9381
# Epoch 102/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3222 - accuracy: 0.9292
# Epoch 103/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1867 - accuracy: 0.9469
# Epoch 104/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2612 - accuracy: 0.9292
# Epoch 105/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1224 - accuracy: 0.9646
# Epoch 106/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1913 - accuracy: 0.9204
# Epoch 107/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3592 - accuracy: 0.8850
# Epoch 108/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1353 - accuracy: 0.9469
# Epoch 109/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1614 - accuracy: 0.9558
# Epoch 110/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2374 - accuracy: 0.9381
# Epoch 111/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1456 - accuracy: 0.9381
# Epoch 112/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2106 - accuracy: 0.9646
# Epoch 113/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1104 - accuracy: 0.9381
# Epoch 114/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1837 - accuracy: 0.9381
# Epoch 115/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2361 - accuracy: 0.9381
# Epoch 116/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0939 - accuracy: 0.9823
# Epoch 117/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0958 - accuracy: 0.9558
# Epoch 118/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1910 - accuracy: 0.9292
# Epoch 119/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1364 - accuracy: 0.9558
# Epoch 120/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0420 - accuracy: 0.9823
# Epoch 121/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1473 - accuracy: 0.9558
# Epoch 122/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2220 - accuracy: 0.9381
# Epoch 123/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1271 - accuracy: 0.9558
# Epoch 124/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2011 - accuracy: 0.9115
# Epoch 125/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1590 - accuracy: 0.9558
# Epoch 126/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2026 - accuracy: 0.9292
# Epoch 127/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1255 - accuracy: 0.9381
# Epoch 128/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2324 - accuracy: 0.9292
# Epoch 129/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2234 - accuracy: 0.9204
# Epoch 130/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2623 - accuracy: 0.9204
# Epoch 131/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1479 - accuracy: 0.9558
# Epoch 132/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2078 - accuracy: 0.9292
# Epoch 133/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1769 - accuracy: 0.9381
# Epoch 134/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0941 - accuracy: 0.9735
# Epoch 135/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0774 - accuracy: 0.9735
# Epoch 136/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1535 - accuracy: 0.9558
# Epoch 137/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1816 - accuracy: 0.9558
# Epoch 138/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1874 - accuracy: 0.9292
# Epoch 139/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0898 - accuracy: 0.9735
# Epoch 140/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2504 - accuracy: 0.9204
# Epoch 141/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0857 - accuracy: 0.9646
# Epoch 142/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0998 - accuracy: 0.9646
# Epoch 143/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1535 - accuracy: 0.9558
# Epoch 144/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0814 - accuracy: 0.9469
# Epoch 145/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1976 - accuracy: 0.9469
# Epoch 146/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1310 - accuracy: 0.9558
# Epoch 147/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1542 - accuracy: 0.9381
# Epoch 148/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1154 - accuracy: 0.9646
# Epoch 149/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1683 - accuracy: 0.9558
# Epoch 150/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2087 - accuracy: 0.9381

# %%
#7 Preprocessing the Input
def clean_text(text):
  tokens = nltk.word_tokenize (text)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens

def bag_of_words (text, vocab):
  tokens = clean_text(text)
  bow = [0]*len(vocab)
  for w in tokens:
    for idx, word in enumerate(vocab):
      if word == w:
        bow[idx]=1
  return np.array (bow)

def pred_class(text, vocab, labels):
  bow = bag_of_words(text, vocab)
  result = model.predict(np.array([bow]))[0] #Extracting probabilities
  thresh = 0.5
  y_pred = [[indx, res] for indx, res in enumerate(result) if res > thresh]
  y_pred.sort(key=lambda x: x[1], reverse=True) #Sorting by values of probability in decreasing order
  return_list = []
  for r in y_pred:
     return_list.append(labels[r[0]]) #Contains labels (tags) for highest probability
  return return_list

def get_response(intents_list, intents_json):
  if len(intents_list) == 0:
    result = "Sorry! I don't understand."
  else:
    tag = intents_list[0]
    list_of_intents = intents_json["intents"]
    for i in list_of_intents:
      if i["tag"] == tag:
        result = random.choice(i["responses"])
        break
  return result

# %%
#8 Interacting with the chatbot
print("Press Ø if you don't want to chat with our ChatBot.")
while True:
  message = input("")
  if message == "0":
    break
  intents=pred_class(message, words, classes)
  result = get_response (intents, data)
  print(result)
# Out:
# Press Ø if you don't want to chat with our ChatBot.
# google
# 1/1 [==============================] - 0s 86ms/step
# Redirecting to Google...
# images
# 1/1 [==============================] - 0s 31ms/step
# Sorry! I don't understand.
# google
# 1/1 [==============================] - 0s 19ms/step
# Redirecting to Google...
# google
# 1/1 [==============================] - 0s 20ms/step
# Redirecting to Google...
#
# 1/1 [==============================] - 0s 34ms/step
# Sorry! I don't understand.
# hey
# 1/1 [==============================] - 0s 22ms/step
# Good to see you again
# bye
# 1/1 [==============================] - 0s 25ms/step
# See you!
# .
# 1/1 [==============================] - 0s 21ms/step
# Sorry! I don't understand.
# who are you
# 1/1 [==============================] - 0s 20ms/step
# I am Ted, a Deep-Learning chatbot
# whats your name
# 1/1 [==============================] - 0s 20ms/step
# All good..What about you?
# what is your name
# 1/1 [==============================] - 0s 20ms/step
# I was made in 2020, if that's what you are asking!
# what you can do
# 1/1 [==============================] - 0s 20ms/step
# I am a general purpose chatbot. My capabilities are :
#  1. I can chat with you. Try asking me for jokes or riddles!
#  2. Ask me the date and time
#  3. I can google search for you. Use format google: your query
#  4. I can get the present weather for any city. Use format weather: city name
#  5. I can get you the top 10 trending news in India. Use keywords 'Latest News'
#  6. I can get you the top 10 trending songs globally. Type 'songs'
#  7. I can set a timer for you. Enter 'set a timer: minutes to timer'
#  8. I can get the present Covid stats for any country. Use 'covid 19: world' or 'covid 19: country name'
#  For suggestions to help me improve, send an email to ted.thedlbot.suggestions@gmail.com . Thank you!!
# what support is offered
# 1/1 [==============================] - 0s 25ms/step
# I am a general purpose chatbot. My capabilities are :
#  1. I can chat with you. Try asking me for jokes or riddles!
#  2. Ask me the date and time
#  3. I can google search for you. Use format google: your query
#  4. I can get the present weather for any city. Use format weather: city name
#  5. I can get you the top 10 trending news in India. Use keywords 'Latest News'
#  6. I can get you the top 10 trending songs globally. Type 'songs'
#  7. I can set a timer for you. Enter 'set a timer: minutes to timer'
#  8. I can get the present Covid stats for any country. Use 'covid 19: world' or 'covid 19: country name'
#  For suggestions to help me improve, send an email to ted.thedlbot.suggestions@gmail.com . Thank you!!
# joke
# 1/1 [==============================] - 0s 29ms/step
# Never criticize someone until you've walked a mile in their shoes. That way, when you criticize them, they won't be able to hear you from that far away. Plus, you'll have their shoes.
# date
# 1/1 [==============================] - 0s 20ms/step
# Date and Time
# weather
# 1/1 [==============================] - 0s 21ms/step
# ...
# how are you
# 1/1 [==============================] - 0s 22ms/step
# Good to see you again
# age
# 1/1 [==============================] - 0s 21ms/step
# I was made in 2020, if that's what you are asking!
# 0
